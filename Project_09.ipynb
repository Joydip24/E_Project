# %%
# import important libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
covid_19 = pd.read_csv('COVID_19.csv')
covid_19.head()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 0         Alabama             US  2020-05-21 02:32:54  32.3182  -86.9023
# 1          Alaska             US  2020-05-21 02:32:54  61.3707 -152.4044
# 2  American Samoa             US  2020-05-21 02:32:54 -14.2710 -170.1320
# 3         Arizona             US  2020-05-21 02:32:54  33.7298 -111.4312
# 4        Arkansas             US  2020-05-21 02:32:54  34.9697  -92.3731
#
#    Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 0      13052     522        NaN  12530.0     1     266.194321       164450.0
# 1        401      10      352.0     39.0     2      54.815493        37045.0
# 2          0       0        NaN      0.0    60       0.000000          124.0
# 3      14906     747     3773.0  10386.0     4     204.788838       165435.0
# 4       5003     107     3852.0   1044.0     5     165.782801        96258.0
#
# ...

# %%
covid_19.tail(3)
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 55  West Virginia             US  2020-05-21 02:32:54  38.4912  -80.9545
# 56      Wisconsin             US  2020-05-21 02:32:54  44.2685  -89.6165
# 57        Wyoming             US  2020-05-21 02:32:54  42.7560 -107.3025
#
#     Confirmed  Deaths  Recovered  Active  FIPS  Incident_Rate  People_Tested  \
# 55       1567      69      950.0   548.0    54      87.437024        80641.0
# 56      13413     481     7728.0  5204.0    55     230.367575       167713.0
# 57        787      11      528.0   248.0    56     135.980607        18840.0
#
#     People_Hospitalized  Mortality_Rate       UID ISO3  Testing_Rate  \
# 55                  NaN        4.403318  84000054  USA   4499.686689
# 56               2161.0        3.586073  84000055  USA   2880.462020
# 57                 74.0        1.397713  84000056  USA   3255.240955
#
#     Hospitalization_Rate
# 55                   NaN
# 56             16.111235
# ...

# %%
covid_19.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate',
#        'People_Tested', 'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3',
#        'Testing_Rate', 'Hospitalization_Rate'],
#       dtype='object')

# %% [raw]
# """
# Columns description
#
# Province_State - The name of the State within the USA.
# Country_Region - The name of the Country (US).
# Last_Update - The most recent date the file was pushed.
# Lat - Latitude.
# Long_ - Longitude.
# Confirmed - Aggregated confirmed case count for the state.
# Deaths - Aggregated Death case count for the state.
# Recovered - Aggregated Recovered case count for the state.
# Active - Aggregated confirmed cases that have not been resolved (Active = Confirmed - Recovered - Deaths).
# FIPS - Federal Information Processing Standards code that uniquely identifies counties within the USA.
# Incident_Rate - confirmed cases per 100,000 persons.
# People_Tested - Total number of people who have been tested.
# People_Hospitalized - Total number of people hospitalized.
# Mortality_Rate - Number recorded deaths * 100/ Number confirmed cases.
# UID - Unique Identifier for each row entry.
# ISO3 - Officialy assigned country code identifiers.
# Testing_Rate - Total number of people tested per 100,000 persons.
# Hospitalization_Rate - Total number of people hospitalized * 100/ Number of confirmed cases.
#
# """

# %%
covid_19.shape
# Out:
# (58, 18)

# %%
covid_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   56 non-null     float64
#  4   Long_                 56 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             42 non-null     float64
#  8   Active                58 non-null     float64
#  9   FIPS                  58 non-null     int64
#  10  Incident_Rate         56 non-null     float64
#  11  People_Tested         56 non-null     float64
#  12  People_Hospitalized   33 non-null     float64
#  13  Mortality_Rate        57 non-null     float64
#  14  UID                   58 non-null     int64
# ...

# %% [markdown]
# # Cleansing of data

# %%
# making a copy of the dataset
covid = covid_19.copy()

# %%
covid['Province_State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'American Samoa', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'Diamond Princess', 'District of Columbia', 'Florida', 'Georgia',
#        'Grand Princess', 'Guam', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Northern Mariana Islands', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Puerto Rico', 'Rhode Island',
#        'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah',
#        'Vermont', 'Virgin Islands', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
# finding idea about object data type columns
print("Province State uniqueness: ", covid['Province_State'].unique(),sep='\n')
print("-"*30)
print(" Value Count: ", covid.Province_State.value_counts(dropna=False),sep = '\n' )
print("*"*50)
print("Country Region uniqueness: ", covid['Country_Region'].unique(),sep='\n')
print("-"*30)
print(" Value Count: ", covid.Country_Region.value_counts(dropna=False),sep = '\n' )
print("*"*50)
print("eLast_Update uniqueness: ", covid['Last_Update'].unique(),sep='\n')
print("-"*30)
print(" Value Count: ", covid.Last_Update.value_counts(dropna=False),sep = '\n' )
print("*"*50)
print("ISO3 uniqueness: ", covid['ISO3'].unique(),sep='\n')
print("-"*30)
print(" Value Count: ", covid.ISO3.value_counts(dropna=False),sep = '\n' )
print("*"*50)
# Out:
# Province State uniqueness:
# ['Alabama' 'Alaska' 'American Samoa' 'Arizona' 'Arkansas' 'California'
#  'Colorado' 'Connecticut' 'Delaware' 'Diamond Princess'
#  'District of Columbia' 'Florida' 'Georgia' 'Grand Princess' 'Guam'
#  'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky'
#  'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire'
#  'New Jersey' 'New Mexico' 'New York' 'North Carolina' 'North Dakota'
#  'Northern Mariana Islands' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Puerto Rico' 'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee'
#  'Texas' 'Utah' 'Vermont' 'Virgin Islands' 'Virginia' 'Washington'
#  'West Virginia' 'Wisconsin' 'Wyoming']
# ------------------------------
#  Value Count:
# California                  1
# Virginia                    1
# Missouri                    1
# Colorado                    1
# Alaska                      1
# ...

# %%
# checking if there are any null value present in the dataset using heatmap
plt.figure(figsize=(12,8))
sns.heatmap(covid.isnull(),cmap="Blues",annot=True)
plt.show()
# we do see there are null value present in lat. long,recovered,people hospitalixed and hospitalization rate

# %%
# checking the null value without using visualization
covid.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %%
print("Recovered uniqueness: ", covid['Recovered'].unique(),sep='\n')
print("-"*30)
print(" Value Count: ", covid.Recovered.value_counts(dropna=False),sep = '\n' )
print("*"*50)

# we can impute the null value by the mean
# Out:
# Recovered uniqueness:
# [       nan 3.5200e+02 3.7730e+03 3.8520e+03 3.4780e+03 6.2640e+03
#  3.9650e+03 1.0590e+03 1.2500e+02 5.7800e+02 1.6680e+03 8.3620e+03
#  4.7300e+02 2.8260e+03 2.6249e+04 1.1000e+03 2.9930e+03 2.8234e+04
#  1.2227e+04 7.6810e+03 4.4000e+02 3.3600e+02 1.2750e+03 2.3945e+04
#  1.8820e+03 6.1886e+04 1.1637e+04 1.3020e+03 1.3000e+01 4.2660e+03
#  1.4060e+03 1.0300e+03 5.4510e+03 3.0230e+03 1.1783e+04 3.0341e+04
#  4.4230e+03 8.2400e+02 6.1000e+01 4.5230e+03 9.5000e+02 7.7280e+03
#  5.2800e+02]
# ------------------------------
#  Value Count:
# NaN        16
# 2826.0      1
# 11637.0     1
# 8362.0      1
# 1302.0      1
# 1882.0      1
# 1275.0      1
# 336.0       1
# 440.0       1
# 1100.0      1
# 473.0       1
# 1406.0      1
# 1668.0      1
# 578.0       1
# 125.0       1
# 1059.0      1
# 6264.0      1
# 3478.0      1
# 3852.0      1
# 352.0       1
# 13.0        1
# 11783.0     1
# 30341.0     1
# 7681.0      1
# 5451.0      1
# 3023.0      1
# ...

# %%
print("People_Hospitalized uniqueness: ", covid['People_Hospitalized'].unique(),sep='\n')
print("-"*30)
print(" Value Count: ", covid.People_Hospitalized.value_counts(dropna=False),sep = '\n' )
# we can impute the null value by the mean
# Out:
# People_Hospitalized uniqueness:
# [1.4930e+03        nan 1.7920e+03 5.3500e+02 3.9550e+03 1.0946e+04
#  8.9340e+03 7.1070e+03 8.2000e+01 2.1500e+02 4.3890e+03 7.6000e+02
#  2.0100e+03 2.3100e+02 7.3930e+03 8.8970e+03 2.3080e+03 1.9010e+03
#  6.5000e+01 3.8300e+02 1.1390e+03 7.6410e+04 1.4200e+02 5.1980e+03
#  9.0500e+02 7.2300e+02 1.4860e+03 1.4440e+03 3.3300e+02 1.5150e+03
#  6.3100e+02 6.0590e+03 2.1610e+03 7.4000e+01]
# ------------------------------
#  Value Count:
# NaN        25
# 6059.0      1
# 231.0       1
# 1139.0      1
# 383.0       1
# 65.0        1
# 1901.0      1
# 2308.0      1
# 8897.0      1
# 2010.0      1
# 4389.0      1
# 760.0       1
# 215.0       1
# 82.0        1
# 535.0       1
# 1792.0      1
# 142.0       1
# 76410.0     1
# 10946.0     1
# 905.0       1
# 723.0       1
# 1486.0      1
# 7393.0      1
# 1444.0      1
# 333.0       1
# 1515.0      1
# 631.0       1
# 74.0        1
# 3955.0      1
# 7107.0      1
# 5198.0      1
# 2161.0      1
# ...

# %%
print("Hospitalization_Rate uniqueness: ", covid['Hospitalization_Rate'].unique(),sep='\n')
print("-"*30)
print(" Value Count: ", covid.Hospitalization_Rate.value_counts(dropna=False),sep = '\n' )
# we can impute the null value by the mean
# Out:
# Hospitalization_Rate uniqueness:
# [11.43885994         nan 12.02200456 10.69358385 17.34877396 28.05443781
#  18.8199111  17.85633527 12.75272162  8.57940942 14.9928264   8.93381921
#  24.61124036 12.69928532 17.46804338 10.         13.06168647 15.88535138
#  13.59832636  9.90175801 18.03071078 21.56220899  6.77804296 17.65864927
#  16.3593637  19.02131018 11.12608565 15.73841962  7.97222887  8.22832935
#   8.18417639 18.41193631 16.11123537  9.40279543]
# ------------------------------
#  Value Count:
# NaN          25
# 18.030711     1
# 12.752722     1
# 8.933819      1
# 13.598326     1
# 16.359364     1
# 14.992826     1
# 9.901758      1
# 18.411936     1
# 9.402795      1
# 21.562209     1
# 15.738420     1
# 8.579409      1
# 28.054438     1
# 17.856335     1
# 10.000000     1
# 8.228329      1
# 7.972229      1
# 11.438860     1
# 6.778043      1
# 17.658649     1
# 17.468043     1
# 8.184176      1
# 17.348774     1
# 18.819911     1
# 10.693584     1
# 15.885351     1
# ...

# %%
# checking the uniqueness and value count of null valued columns

print("Incident Rate uniqueness: ", covid['Incident_Rate'].unique(),sep='\n')
print("-"*30)
print(" Value Count: ", covid.Incident_Rate.value_counts(dropna=False),sep = '\n' )
print("*"*60)
print("People_Tested uniqueness: ", covid['People_Tested'].unique(),sep='\n')
print("-"*30)
print(" Value Count: ", covid.People_Tested.value_counts(dropna=False),sep = '\n' )
print("*"*60)
print("Mortality_Rate uniqueness: ", covid['Mortality_Rate'].unique(),sep='\n')
print("-"*30)
print(" Value Count: ", covid.Mortality_Rate.value_counts(dropna=False),sep = '\n' )
print("*"*60)
print("Testing_Rate uniqueness: ", covid['Testing_Rate'].unique(),sep='\n')
print("-"*30)
print(" Value Count: ", covid.Testing_Rate .value_counts(dropna=False),sep = '\n' )
print("*"*60)
# we can impute the null value by the mean
# Out:
# Incident Rate uniqueness:
# [ 266.19432063   54.81549324    0.          204.78883847  165.782801
#   217.64657483  395.86812106 1094.35790162  841.47699032           nan
#  1069.92712707  221.02421684  374.8649743    93.77150199   45.41370971
#   140.22993008  792.45121913  434.83433917  495.07617898  292.00422612
#   182.80209854  759.68089788  135.32091664  700.05359199 1290.82279689
#   530.78761416  313.31831581  402.09680362  187.83112405   44.72397448
#   574.95626569  239.85798122  284.47221505 1697.50928544  301.2644331
#  1821.62021647  193.19067239  274.91201503   38.08211229  251.82434918
#   139.80390556   90.11941712  532.15168362   97.70205849 1260.7600242
#   178.19983786  472.15932919  269.60800823  178.20807031  240.48973817
#   151.28471816   64.32486855  385.54187508  249.13022415   87.43702386
#   230.3675748   135.98060678]
# ------------------------------
#  Value Count:
# NaN            2
# 64.324869      1
# 532.151684     1
# 284.472215     1
# ...

# %%
# finding the mean value of each columns of null value

print(" Incident Rate_Mean: ", covid.Incident_Rate.mean(), sep = '\n' )
print("*"*60)
print(" People_Tested_Mean: ", covid.People_Tested.mean(), sep = '\n' )
print("*"*60)
print(" Mortality_Rate_Mean: ", covid.Mortality_Rate.mean(), sep = '\n' )
print("*"*60)
print(" Testing_Rate_Mean: ", covid.Testing_Rate.mean(), sep = '\n' )
print("*"*60)
print(" Hospitalization_Rate_Mean: ", covid.Hospitalization_Rate.mean(), sep = '\n' )
print("*"*60)
print(" People_Hospitalized_Mean: ", covid.People_Hospitalized.mean(), sep = '\n' )
print("*"*60)
print(" Recovered_Mean: ", covid.Recovered.mean(), sep = '\n' )
# Out:
#  Incident Rate_Mean:
# 396.23080551083666
# ************************************************************
#  People_Tested_Mean:
# 225853.4107142857
# ************************************************************
#  Mortality_Rate_Mean:
# 4.458247989218647
# ************************************************************
#  Testing_Rate_Mean:
# 3894.186869685221
# ************************************************************
#  Hospitalization_Rate_Mean:
# 14.342541433640415
# ************************************************************
#  People_Hospitalized_Mean:
# 4897.454545454545
# ************************************************************
#  Recovered_Mean:
# 7007.428571428572

# %%
# imputing the null value using fillna
covid = covid.fillna({'Incident_Rate': 396})
covid = covid.fillna({'People_Tested': 225853})
covid = covid.fillna({'Mortality_Rate': 4})
covid = covid.fillna({'Testing_Rate': 3894})
covid = covid.fillna({'Hospitalization_Rate': 14})
covid = covid.fillna({'People_Hospitalized': 4897})
covid = covid.fillna({'Recovered': 7007})

# %%
covid.isnull().sum()
# Out:
# Province_State          0
# Country_Region          0
# Last_Update             0
# Lat                     2
# Long_                   2
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# FIPS                    0
# Incident_Rate           0
# People_Tested           0
# People_Hospitalized     0
# Mortality_Rate          0
# UID                     0
# ISO3                    0
# Testing_Rate            0
# Hospitalization_Rate    0
# dtype: int64

# %%
# dropping lat, long, Country_Region, Last_Update, IS03 ,FIPS & UID columns, as they are all unique no
covid.drop(['Lat', 'Long_', 'Country_Region','FIPS', 'Last_Update', 'UID', 'ISO3'], inplace=True, axis=1)

# %%
covid.shape
# after droping columns
# Out:
# (58, 11)

# %%
covid.info()
# as we see that their are objet dtype we'll convert them to int dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Confirmed             58 non-null     int64
#  2   Deaths                58 non-null     int64
#  3   Recovered             58 non-null     float64
#  4   Active                58 non-null     float64
#  5   Incident_Rate         58 non-null     float64
#  6   People_Tested         58 non-null     float64
#  7   People_Hospitalized   58 non-null     float64
#  8   Mortality_Rate        58 non-null     float64
#  9   Testing_Rate          58 non-null     float64
#  10  Hospitalization_Rate  58 non-null     float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 5.1+ KB

# %%
# Importing label encoder to convert the dtype
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

# making a copy of dataset 
covid_data = covid.copy()

covid_data['Province_State'] = label_encoder.fit_transform(covid_data['Province_State'])

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     int32
#  1   Confirmed             58 non-null     int64
#  2   Deaths                58 non-null     int64
#  3   Recovered             58 non-null     float64
#  4   Active                58 non-null     float64
#  5   Incident_Rate         58 non-null     float64
#  6   People_Tested         58 non-null     float64
#  7   People_Hospitalized   58 non-null     float64
#  8   Mortality_Rate        58 non-null     float64
#  9   Testing_Rate          58 non-null     float64
#  10  Hospitalization_Rate  58 non-null     float64
# dtypes: float64(8), int32(1), int64(2)
# memory usage: 4.9 KB

# %% [markdown]
# # Summary Statistics

# %%
covid_data.describe()
# Out:
#        Province_State      Confirmed        Deaths     Recovered  \
# count       58.000000      58.000000     58.000000     58.000000
# mean        28.500000   26756.086207   1611.017241   7007.310345
# std         16.886879   52562.031122   4084.750891   9901.304547
# min          0.000000       0.000000      0.000000     13.000000
# 25%         14.250000    2596.000000     74.000000   1281.750000
# 50%         28.500000   10148.500000    385.000000   4987.000000
# 75%         42.750000   29395.500000   1394.250000   7007.000000
# max         57.000000  354370.000000  28636.000000  61886.000000
#
#               Active  Incident_Rate  People_Tested  People_Hospitalized  \
# count      58.000000      58.000000   5.800000e+01            58.000000
# mean    20070.724138     396.222847   2.258534e+05          4897.258621
# std     41294.705318     395.554854   2.934948e+05          9879.577792
# min         0.000000       0.000000   1.240000e+02            65.000000
# ...

# %% [raw]
# """
# Findings
# 1. There are differences in mean and 50% in most of the columns
# 2. There are differences in 75% and max values
#
# """

# %%
covid_data.shape
# Out:
# (58, 11)

# %%
covid_data['Deaths'].unique()
# Out:
# array([  522,    10,     0,   747,   107,  3497,  1299,  3529,   310,
#          407,  2096,  1697,     3,     5,    17,    77,  4525,  1864,
#          393,   202,   376,  2608,    73,  2123,  6066,  5060,   786,
#          570,   640,    16,   138,   377,   190, 10749,   283, 28636,
#          726,    49,     2,  1781,   299,   144,  4770,   125,   538,
#           46,   305,  1426,    90,    54,     6,  1075,  1037,    69,
#          481,    11], dtype=int64)

# %%
covid_data['Recovered'].unique()
# Out:
# array([7.0070e+03, 3.5200e+02, 3.7730e+03, 3.8520e+03, 3.4780e+03,
#        6.2640e+03, 3.9650e+03, 1.0590e+03, 1.2500e+02, 5.7800e+02,
#        1.6680e+03, 8.3620e+03, 4.7300e+02, 2.8260e+03, 2.6249e+04,
#        1.1000e+03, 2.9930e+03, 2.8234e+04, 1.2227e+04, 7.6810e+03,
#        4.4000e+02, 3.3600e+02, 1.2750e+03, 2.3945e+04, 1.8820e+03,
#        6.1886e+04, 1.1637e+04, 1.3020e+03, 1.3000e+01, 4.2660e+03,
#        1.4060e+03, 1.0300e+03, 5.4510e+03, 3.0230e+03, 1.1783e+04,
#        3.0341e+04, 4.4230e+03, 8.2400e+02, 6.1000e+01, 4.5230e+03,
#        9.5000e+02, 7.7280e+03, 5.2800e+02])

# %% [markdown]
# # Data Visualization

# %%
covid_data.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C425D0F0C8>,
# ...
#       dtype=object)

# %%
# Findings what are the conformned cases with respect to Privinces_State
sns.factorplot('Confirmed','Province_State',data=covid,size=12,aspect=0.8,palette='winter',join=False)

# %%
#lets check how Deaths is changing with respect to Privinces_State
sns.factorplot('Deaths','Province_State',data=covid,size=12,aspect=0.8,palette='winter',join=False)

# %%
# Findings hor recovery is changing with respect to Privinces_State
sns.factorplot('Recovered','Province_State',data=covid,size=12,aspect=0.8,palette='winter',join=False)

# %%
# Findings how active is civid_19 with respect to Privinces_State
sns.factorplot('Active','Province_State',data=covid,size=12,aspect=0.8,palette='winter',join=False)

# %%
# Findings what is the Testing_Rate with respect to Privinces_State
sns.factorplot('Testing_Rate','Province_State',data=covid,size=12,aspect=0.8,palette='winter',join=False)

# %%
# Findings what is the Hospitalization_Rate with respect to Privinces_State
sns.factorplot('Hospitalization_Rate','Province_State',data=covid,size=12,aspect=0.8,palette='winter',join=False)

# %%
# Findings what is the Mortality_Rate with respect to Privinces_State
sns.factorplot('Mortality_Rate','Province_State',data=covid,size=12,aspect=0.8,palette='winter',join=False)

# %%
# Installing and importing important libraries for graphical representation 
# !pip install plotly==3.10
import plotly.plotly as po
import plotly.figure_factory as ff
import numpy as np
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
# Out:
# ...
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
dataframe = covid
data = dataframe.loc[:,['Province_State', 'Confirmed', 'Deaths', 'Recovered', 'Active',
       'Incident_Rate', 'People_Tested', 'People_Hospitalized',
       'Mortality_Rate', 'Testing_Rate', 'Hospitalization_Rate']]
data["index"] = np.arange(1, len(data) + 1)

fig = ff.create_scatterplotmatrix(data, diag = 'box', index = 'index', colormap = 'Portland',
                                  colormap_type = 'cat',
                                  height = 1000, width = 1000)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="b9d220df-0b1f-4f34-9e43-8c9368779ab3" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b9d220df-0b1f-4f34-9e43-8c9368779ab3")) {
#                     Plotly.newPlot(
#                         'b9d220df-0b1f-4f34-9e43-8c9368779ab3',
# ...

# %%
#lets check how Deaths is changing with respect to Confirmed Cases
plt.figure(figsize=(8,5))
plt.scatter(covid_data['Deaths'],covid_data['Confirmed'])
plt.title("Deaths Vs Confirmed Cases ")
plt.ylabel("Confirmed")
plt.xlabel("Deaths")
plt.show()

# %%
#lets check how Recovered is changing with respect to Confirmed Cases
plt.figure(figsize=(18,5))
sns.lineplot(x=covid_data["Recovered"],y=covid_data["Confirmed"],data=covid_data)
plt.title("Recovered Vs Confirmed ")
plt.ylabel("Confirmed")
plt.xlabel("Recovered")
plt.show()

# %%
plt.figure(figsize=(18,10))
sns.set()
sns.set_context("paper")
sns.swarmplot(x="Active", y="Confirmed", data=covid_data)
plt.title("Active Vs Confirmed ")
plt.ylabel("Confirmed")
plt.xlabel("Active")
plt.show()

# %%
#lets check how Mortality_Rate is changing with respect to Confirmed Cases
plt.figure(figsize=(8,5))
plt.scatter(covid_data['Mortality_Rate'],covid_data['Confirmed'])
plt.title("Mortality_Rate Vs Confirmed Cases ")
plt.ylabel("Confirmed")
plt.xlabel("Mortality_Rate")
plt.show()

# %%
#lets check howPeople_Hospitalized is changing with respect to Confirmed Cases
sns.jointplot(x='People_Hospitalized', y='Confirmed', data = covid_data, color = 'Red')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='Mortality_Rate', y='Confirmed', data = covid_data, color ='blue')
plt.title(" Average Price Across the Years")
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.title("Distribution of Confirmed Cases")
price = covid['Confirmed'].values
sns.distplot(price, color = 'blue')

# %%
plt.figure(figsize=(12,8))
plt.title("Distribution of Deaths")
price = covid['Deaths'].values
sns.distplot(price, color = 'red')

# %%
# Bivariate Analysis
sns.pairplot(covid_data)

# %% [markdown]
# # Checking Correlation

# %%
dfcor=covid_data.corr()
dfcor
# Out:
#                       Province_State  Confirmed    Deaths  Recovered  \
# Province_State              1.000000   0.006490  0.015229   0.067599
# Confirmed                   0.006490   1.000000  0.982191   0.822545
# Deaths                      0.015229   0.982191  1.000000   0.830222
# Recovered                   0.067599   0.822545  0.830222   1.000000
# Active                     -0.027612   0.985218  0.954378   0.725081
# Incident_Rate              -0.078259   0.708447  0.710113   0.542795
# People_Tested              -0.065428   0.824136  0.739634   0.711250
# People_Hospitalized         0.005462   0.869268  0.908279   0.761826
# Mortality_Rate              0.025042   0.384315  0.428452   0.322030
# Testing_Rate                0.083187   0.332466  0.344466   0.220601
# Hospitalization_Rate       -0.130008   0.287684  0.299218   0.226429
#
#                         Active  Incident_Rate  People_Tested  \
# Province_State       -0.027612      -0.078259      -0.065428
# ...

# %%
# visual representation of correlation using heatmap
plt.figure(figsize=(12,8))
sns.heatmap(dfcor,cmap='BuPu', annot=True,fmt='0.2f', linewidths=0.5)

# %% [markdown]
# # Plotting Outliers

# %%
covid_data.shape
# Out:
# (58, 11)

# %%
collist = covid_data.columns.values
ncol = 11
nrows = 10

# %%
plt.figure(figsize=(2*ncol,10*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(covid_data[collist[i]],orient='v',color='blue')
    plt.tight_layout()

# %%
# finding outliers if there are any in the dataset

from scipy.stats import zscore
z_score=abs(zscore(covid_data))
print(covid_data.shape)
df_covid=covid_data.loc[(z_score<3).all(axis=1)]
print(df_covid.shape)
# outliners have been removed and the new shape of the dataset is reflection below
# Out:
# (58, 11)
# (53, 11)

# %% [markdown]
# # Checking Skewness

# %%
df_covid.skew()
# data reflecting positive skewness
# Out:
# Province_State          0.019751
# Confirmed               2.054444
# Deaths                  2.371053
# Recovered               2.444600
# Active                  2.625579
# Incident_Rate           1.702220
# People_Tested           1.789453
# People_Hospitalized     0.081780
# Mortality_Rate          0.540345
# Testing_Rate            0.594055
# Hospitalization_Rate    0.269323
# dtype: float64

# %%
plt.figure(figsize=(23,36))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df_covid[collist[i]])

# %%
# treating skewness with log transformation
import numpy as np
for col in df_covid.columns:
    if df_covid.skew().loc[col]>0.55:
        df_covid[col]=np.log1p(df_covid[col])
print(df_covid.skew())
# Out:
# Province_State          0.019751
# Confirmed              -1.502105
# Deaths                 -0.698535
# Recovered              -1.288631
# Active                 -1.039823
# Incident_Rate          -2.278870
# People_Tested          -1.799022
# People_Hospitalized     0.081780
# Mortality_Rate          0.540345
# Testing_Rate           -3.236223
# Hospitalization_Rate    0.269323
# dtype: float64

# %% [markdown]
# # Seperating input and output for Regression

# %%
# defining x and y 
x = df_covid.drop("Deaths",axis=1)
y = df_covid["Deaths"].copy()

# %%
x.head(3)
# Out:
#    Province_State  Confirmed  Recovered    Active  Incident_Rate  \
# 0               0   9.476773   8.854808  9.435961       5.587976
# 1               1   5.996452   5.866468  3.688879       4.022051
# 2               2   0.000000   8.854808  0.000000       0.000000
#
#    People_Tested  People_Hospitalized  Mortality_Rate  Testing_Rate  \
# 0      12.010368               1493.0        3.999387      8.118190
# 1      10.519916               4897.0        2.493766      8.530098
# 2       4.828314               4897.0        4.000000      5.411009
#
#    Hospitalization_Rate
# 0              11.43886
# 1              14.00000
# 2              14.00000

# %%
y.head(3)
# Out:
# 0    6.259581
# 1    2.397895
# 2    0.000000
# Name: Deaths, dtype: float64

# %%
x.shape
# Out:
# (53, 10)

# %%
y.shape
# Out:
# (53,)

# %%
# Scaling down using standard scaler

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[-1.71855347e+00,  4.32552175e-01,  6.01197445e-01,
#          6.57281448e-01,  1.86294318e-01,  3.97683454e-01,
#         -8.46343281e-01, -1.30296025e-01,  9.85114036e-02,
#         -7.48014829e-01],
#        [-1.65886583e+00, -1.09530979e+00, -1.39337503e+00,
#         -1.48912360e+00, -1.24711922e+00, -5.22961228e-01,
#          5.90392050e-01, -8.83545492e-01,  6.87478376e-01,
#          4.33695548e-02],
#        [-1.59917819e+00, -3.72775393e+00,  6.01197445e-01,
#         -2.86683672e+00, -4.92881798e+00, -4.03863439e+00,
#          5.90392050e-01, -1.29989380e-01, -3.77235676e+00,
#          4.33695548e-02],
#        [-1.53949056e+00,  4.90857079e-01,  1.88100273e-01,
#          5.87198208e-01, -5.27343968e-02,  4.01372179e-01,
#         -7.20143556e-01,  3.76007738e-01, -4.57638122e-01,
#         -5.67824940e-01],
#        [-1.47980292e+00,  1.16473125e-02,  2.01927616e-01,
#         -2.70506896e-01, -2.45108671e-01,  6.68645167e-02,
# ...

# %% [markdown]
# # Data ready for  ML

# %%
# importing important libraries

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso
from sklearn.ensemble import GradientBoostingRegressor

# %%
# finding best random state between 42 to 100 with test_size=0.22
max_r_score = 0
for r_state in range(42,101):
    x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = r_state, test_size=0.22)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    y_predict = lr.predict(x_test)
    r2_scr = r2_score(y_test, y_predict)
    print("r2_score corresponding to random state: ",r_state," is: ", r2_scr)
    if r2_scr > max_r_score:
        max_r_score = r2_scr
        final_r_state = r_state
    print()
    print()
    print("Maximum r2 score corresponding to",final_r_state, "is ",max_r_score)
# Out:
# r2_score corresponding to random state:  42  is:  0.9967767130914489
#
#
# Maximum r2 score corresponding to 42 is  0.9967767130914489
# r2_score corresponding to random state:  43  is:  0.9872966037398132
#
#
# Maximum r2 score corresponding to 42 is  0.9967767130914489
# r2_score corresponding to random state:  44  is:  0.9846098163726807
#
#
# Maximum r2 score corresponding to 42 is  0.9967767130914489
# r2_score corresponding to random state:  45  is:  0.8289724563919151
#
#
# Maximum r2 score corresponding to 42 is  0.9967767130914489
# r2_score corresponding to random state:  46  is:  0.9950219684754517
#
#
# Maximum r2 score corresponding to 42 is  0.9967767130914489
# r2_score corresponding to random state:  47  is:  0.9743794313792545
#
#
# Maximum r2 score corresponding to 42 is  0.9967767130914489
# r2_score corresponding to random state:  48  is:  -24.574027684156288
#
#
# Maximum r2 score corresponding to 42 is  0.9967767130914489
# ...

# %%
# Since the maximum r2 score is coming around 0.9967 with random state 42.
# However checking with other models to see if we get any better score 
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=42,test_size=0.22)

# %%
x_train.shape
# Out:
# (41, 10)

# %%
y_train.shape
# Out:
# (41,)

# %%
x_test.shape
# Out:
# (12, 10)

# %%
y_test.shape
# Out:
# (12,)

# %%
# finding the best parameters for each model using gridsearchCV

# %%
svr=SVR()
parameters = {'kernel':('linear','poly','rbf'), 'C':[1,10]}
svgs = GridSearchCV(svr, parameters, cv = 5)
svgs.fit(x_train,y_train)
svgs.best_params_
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
knn = KNeighborsRegressor()
parameters = {'n_neighbors':range(1,30)}
knngs = GridSearchCV(knn, parameters, cv = 5)
knngs.fit(x_train, y_train)
knngs.best_params_
# Out:
# {'n_neighbors': 2}

# %%
rfr = RandomForestRegressor()
parameters = {'n_estimators':[50,100,150,200,250,300]}
rfgs = GridSearchCV(rfr, parameters, cv = 5)
rfgs.fit(x_train, y_train)
rfgs.best_params_
# Out:
# {'n_estimators': 300}

# %%
dtr = DecisionTreeRegressor()
parameters = {'criterion':('mse','friendman_mse', 'mse')}
dtgs = GridSearchCV(dtr, parameters, cv = 5)
dtgs.fit(x_train, y_train)
dtgs.best_params_
# Out:
# {'criterion': 'mse'}

# %%
lso = Lasso()
parameters = {'alpha':[0.001,0.01,0.1,1]}
lsgs = GridSearchCV(lso, parameters, cv = 5)
lsgs.fit(x_train, y_train)
lsgs.best_params_
# Out:
# {'alpha': 0.01}

# %%
gbr = GradientBoostingRegressor()
parameters = {'learning_rate':[0.001,0.01,0.1,1], 'n_estimators':[10,100,500,1000]}
gbgs = GridSearchCV(gbr, parameters, cv = 5)
gbgs.fit(x_train, y_train)
gbgs.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 1000}

# %%
lr = LinearRegression()
svr = SVR(C=1, kernel = 'linear')
knn = KNeighborsRegressor(n_neighbors = 2)
rfr = RandomForestRegressor(n_estimators = 300)
dtr = DecisionTreeRegressor(criterion ='mse')
lso = Lasso(alpha =0.01 )
gbr = GradientBoostingRegressor(learning_rate = 0.1, n_estimators = 1000)

# %%
models = []
models.append(('LineatRegression', lr))
models.append(('SVR', svr))
models.append(('KNeighborsRegressor', knn))
models.append(('RandomForestRegressor', rfr))
models.append(('DecisionTreeRegressor', dtr))
models.append(('Lasso', lso))
models.append(('GradientBoostingRegressor', gbr))

# %%
# Testing all required models with best parameters calculated

Model = []
score = []
rmse = []
mae = []
mse = []
cvs = []
std = []

for name,model in models:
    print ('******************', name ,'********************')
    print("\n")
    Model.append(name)
    model.fit(x_train, y_train)
    print(model)
    pred = model.predict(x_test)
    print("\n")
    rscore = r2_score(y_test, pred)
    print("r2 Score =", rscore)
    score.append(rscore*100)
    print("\n")
    RMS = np.sqrt(mean_squared_error(y_test, pred))
    print("RMSE =", RMS)
    rmse.append(RMS*100)
    print("\n")
    MA = mean_absolute_error(y_test, pred)
    print("MAE =", MA)
    mae.append(MA*100)
    print("\n")
    MS = mean_squared_error(y_test, pred)
    print("MSE =", MS)
    mse.append(MS*100)
    print("\n")
    cvscore = cross_val_score(model, x, y, cv = 10).mean()
    print("Cross_Val_Score =", cvscore)
    cvs.append(cvscore*100)
    print("\n")
    stdscore = cross_val_score(model, x, y, cv = 10).std()
    print("Standard Deviation =", stdscore)
    std.append(stdscore*100)
    print("\n\n")
# Out:
# ****************** LineatRegression ********************
#
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
#
# r2 Score = 0.9967767130914489
#
#
# RMSE = 0.0993859819068116
#
#
# MAE = 0.07687511656450753
#
#
# MSE = 0.00987757339958108
#
#
# Cross_Val_Score = -2.7996801789375487
#
#
# Standard Deviation = 11.190817526442997
#
#
#
# ****************** SVR ********************
#
#
# SVR(C=1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
#
#
# r2 Score = 0.9978339484753014
#
#
# RMSE = 0.08147231226861261
#
#
# MAE = 0.05569788269163487
#
#
# MSE = 0.006637737666394324
#
#
# Cross_Val_Score = 0.9265517276465911
#
#
# Standard Deviation = 0.07813563733017233
#
#
#
# ****************** KNeighborsRegressor ********************
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
# ...

# %%
import pandas as pd
result = pd.DataFrame({'Model': Model, 'r2_score': score, 'Root_mean_square': rmse, 'Mean_absolute_error': mse, 'Mean_square_error': mse, 'Cross_val_score_mean': cvs, 'Cross_val_score_Std': std})
result
# Out:
#                        Model   r2_score  Root_mean_square  \
# 0           LineatRegression  99.677671          9.938598
# 1                        SVR  99.783395          8.147231
# 2        KNeighborsRegressor  85.883014         65.772847
# 3      RandomForestRegressor  92.240408         48.763525
# 4      DecisionTreeRegressor  84.692546         68.489994
# 5                      Lasso  99.414966         13.389557
# 6  GradientBoostingRegressor  94.545579         40.883679
#
#    Mean_absolute_error  Mean_square_error  Cross_val_score_mean  \
# 0             0.987757           0.987757           -279.968018
# 1             0.663774           0.663774             92.655173
# 2            43.260675          43.260675             72.032684
# 3            23.778813          23.778813             83.736345
# 4            46.908793          46.908793             75.026612
# 5             1.792802           1.792802             93.462330
# ...

# %%
# The above result shows that Support Vector Regressorr is giving the best result

# %%
from sklearn.externals import joblib
joblib.dump(svr,'Covid_19_Deaths.obj')
# Out:
# ['Covid_19_Deaths.obj']

# %%
model=joblib.load('Covid_19_Deaths.obj')

# %%
model.predict(x_test)
# Out:
# array([6.15960526, 5.91635613, 1.95455843, 1.70882676, 5.73426383,
#        7.24321059, 5.96958711, 4.23776554, 6.64022487, 5.68253443,
#        2.84654775, 5.95821407])

# %% [markdown]
# # Seperating input and output for Regression

# %%
# defining x and y 
x = df_covid.drop("Deaths",axis=1)
y = df_covid["Recovered"].copy()

# %%
x.head(3)
# Out:
#    Province_State  Confirmed  Recovered    Active  Incident_Rate  \
# 0               0   9.476773   8.854808  9.435961       5.587976
# 1               1   5.996452   5.866468  3.688879       4.022051
# 2               2   0.000000   8.854808  0.000000       0.000000
#
#    People_Tested  People_Hospitalized  Mortality_Rate  Testing_Rate  \
# 0      12.010368               1493.0        3.999387      8.118190
# 1      10.519916               4897.0        2.493766      8.530098
# 2       4.828314               4897.0        4.000000      5.411009
#
#    Hospitalization_Rate
# 0              11.43886
# 1              14.00000
# 2              14.00000

# %%
y.head(3)
# Out:
# 0    8.854808
# 1    5.866468
# 2    8.854808
# Name: Recovered, dtype: float64

# %%
x.shape
# Out:
# (53, 10)

# %%
y.shape
# Out:
# (53,)

# %%
# Scaling down using standard scaler

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[-1.71855347e+00,  4.32552175e-01,  6.01197445e-01,
#          6.57281448e-01,  1.86294318e-01,  3.97683454e-01,
#         -8.46343281e-01, -1.30296025e-01,  9.85114036e-02,
#         -7.48014829e-01],
#        [-1.65886583e+00, -1.09530979e+00, -1.39337503e+00,
#         -1.48912360e+00, -1.24711922e+00, -5.22961228e-01,
#          5.90392050e-01, -8.83545492e-01,  6.87478376e-01,
#          4.33695548e-02],
#        [-1.59917819e+00, -3.72775393e+00,  6.01197445e-01,
#         -2.86683672e+00, -4.92881798e+00, -4.03863439e+00,
#          5.90392050e-01, -1.29989380e-01, -3.77235676e+00,
#          4.33695548e-02],
#        [-1.53949056e+00,  4.90857079e-01,  1.88100273e-01,
#          5.87198208e-01, -5.27343968e-02,  4.01372179e-01,
#         -7.20143556e-01,  3.76007738e-01, -4.57638122e-01,
#         -5.67824940e-01],
#        [-1.47980292e+00,  1.16473125e-02,  2.01927616e-01,
#         -2.70506896e-01, -2.45108671e-01,  6.68645167e-02,
# ...

# %%
# importing important libraries

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso
from sklearn.ensemble import GradientBoostingRegressor

# %%
# finding best random state between 42 to 100 with test_size=0.22
max_r_score = 0
for r_state in range(42,101):
    train_x, test_x, train_y, test_y = train_test_split(x, y, random_state = r_state, test_size=0.22)
    lr = LinearRegression()
    lr.fit(train_x, train_y)
    pred_y = lr.predict(test_x)
    r2_scr = r2_score(test_y, pred_y)
    print("r2_score corresponding to random state: ",r_state," is: ", r2_scr)
    if r2_scr > max_r_score:
        max_r_score = r2_scr
        final_r_state = r_state
    print()
    print()
    print("Maximum r2 score corresponding to",final_r_state, "is ",max_r_score)
# Out:
# r2_score corresponding to random state:  42  is:  1.0
#
#
# Maximum r2 score corresponding to 42 is  1.0
# r2_score corresponding to random state:  43  is:  1.0
#
#
# Maximum r2 score corresponding to 42 is  1.0
# r2_score corresponding to random state:  44  is:  1.0
#
#
# Maximum r2 score corresponding to 42 is  1.0
# r2_score corresponding to random state:  45  is:  1.0
#
#
# Maximum r2 score corresponding to 42 is  1.0
# r2_score corresponding to random state:  46  is:  1.0
#
#
# Maximum r2 score corresponding to 42 is  1.0
# r2_score corresponding to random state:  47  is:  1.0
#
#
# Maximum r2 score corresponding to 42 is  1.0
# r2_score corresponding to random state:  48  is:  1.0
#
#
# Maximum r2 score corresponding to 42 is  1.0
# r2_score corresponding to random state:  49  is:  1.0
#
#
# Maximum r2 score corresponding to 42 is  1.0
# r2_score corresponding to random state:  50  is:  1.0
#
#
# Maximum r2 score corresponding to 42 is  1.0
# ...

# %%
# Since the maximum r2 score is coming around 1 with random state 42.
# However checking with other models to see if we get any better score 
train_x, test_x, train_y, test_y = train_test_split(x,y,random_state=42,test_size=0.22)

# %%
train_x.shape
# Out:
# (41, 10)

# %%
train_y.shape
# Out:
# (41,)

# %%
test_x.shape
# Out:
# (12, 10)

# %%
test_y.shape
# Out:
# (12,)

# %%
# finding the best parameters for each model using gridsearchCV

# %%
svr=SVR()
parameters = {'kernel':('linear','poly','rbf'), 'C':[1,10]}
svgs = GridSearchCV(svr, parameters, cv = 5)
svgs.fit(train_x,train_y)
svgs.best_params_
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
knn = KNeighborsRegressor()
parameters = {'n_neighbors':range(1,30)}
knngs = GridSearchCV(knn, parameters, cv = 5)
knngs.fit(train_x,train_y)
knngs.best_params_
# Out:
# {'n_neighbors': 2}

# %%
rfr = RandomForestRegressor()
parameters = {'n_estimators':[50,100,150,200,250,300]}
rfgs = GridSearchCV(rfr, parameters, cv = 5)
rfgs.fit(train_x,train_y)
rfgs.best_params_
# Out:
# {'n_estimators': 250}

# %%
dtr = DecisionTreeRegressor()
parameters = {'criterion':('mse','friendman_mse', 'mse')}
dtgs = GridSearchCV(dtr, parameters, cv = 5)
dtgs.fit(train_x,train_y)
dtgs.best_params_
# Out:
# {'criterion': 'mse'}

# %%
lso = Lasso()
parameters = {'alpha':[0.001,0.01,0.1,1]}
lsgs = GridSearchCV(lso, parameters, cv = 5)
lsgs.fit(train_x,train_y)
lsgs.best_params_
# Out:
# {'alpha': 0.001}

# %%
gbr = GradientBoostingRegressor()
parameters = {'learning_rate':[0.001,0.01,0.1,1], 'n_estimators':[10,100,500,1000]}
gbgs = GridSearchCV(gbr, parameters, cv = 5)
gbgs.fit(train_x,train_y)
gbgs.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 500}

# %%
lr = LinearRegression()
svr = SVR(C=1, kernel = 'linear')
knn = KNeighborsRegressor(n_neighbors = 2)
rfr = RandomForestRegressor(n_estimators = 250)
dtr = DecisionTreeRegressor(criterion ='mse')
lso = Lasso(alpha =0.001 )
gbr = GradientBoostingRegressor(learning_rate = 0.01, n_estimators = 500)

# %%
models = []
models.append(('LineatRegression', lr))
models.append(('SVR', svr))
models.append(('KNeighborsRegressor', knn))
models.append(('RandomForestRegressor', rfr))
models.append(('DecisionTreeRegressor', dtr))
models.append(('Lasso', lso))
models.append(('GradientBoostingRegressor', gbr))

# %%
# Testing all required models with best parameters calculated

Model = []
score = []
rmse = []
mae = []
mse = []
cvs = []
std = []

for name,model in models:
    print ('******************', name ,'********************')
    print("\n")
    Model.append(name)
    model.fit(train_x,train_y)
    print(model)
    pred = model.predict(test_x)
    print("\n")
    rscore = r2_score(test_y, pred)
    print("r2 Score =", rscore)
    score.append(rscore*100)
    print("\n")
    RMS = np.sqrt(mean_squared_error(test_y, pred))
    print("RMSE =", RMS)
    rmse.append(RMS*100)
    print("\n")
    MA = mean_absolute_error(test_y, pred)
    print("MAE =", MA)
    mae.append(MA*100)
    print("\n")
    MS = mean_squared_error(test_y, pred)
    print("MSE =", MS)
    mse.append(MS*100)
    print("\n")
    cvscore = cross_val_score(model, x, y, cv = 10).mean()
    print("Cross_Val_Score =", cvscore)
    cvs.append(cvscore*100)
    print("\n")
    stdscore = cross_val_score(model, x, y, cv = 10).std()
    print("Standard Deviation =", stdscore)
    std.append(stdscore*100)
    print("\n\n")
# Out:
# ****************** LineatRegression ********************
#
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
#
# r2 Score = 1.0
#
#
# RMSE = 1.9186846773327266e-15
#
#
# MAE = 1.6283271027835629e-15
#
#
# MSE = 3.681350891031389e-30
#
#
# Cross_Val_Score = 1.0
#
#
# Standard Deviation = 0.0
#
#
#
# ****************** SVR ********************
#
#
# SVR(C=1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
#
#
# r2 Score = 0.997595565599831
#
#
# RMSE = 0.07542709996217034
#
#
# MAE = 0.06588000838152193
#
#
# MSE = 0.005689247408703237
#
#
# Cross_Val_Score = 0.985478872904628
#
#
# Standard Deviation = 0.028624840090236373
#
#
#
# ****************** KNeighborsRegressor ********************
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=2, p=2,
# ...

# %%
import pandas as pd
result = pd.DataFrame({'Model': Model, 'r2_score': score, 'Root_mean_square': rmse, 'Mean_absolute_error': mse, 'Mean_square_error': mse, 'Cross_val_score_mean': cvs, 'Cross_val_score_Std': std})
result
# Out:
#                        Model    r2_score  Root_mean_square  \
# 0           LineatRegression  100.000000      1.918685e-13
# 1                        SVR   99.759557      7.542710e+00
# 2        KNeighborsRegressor   78.395043      7.149862e+01
# 3      RandomForestRegressor   95.415978      3.293398e+01
# 4      DecisionTreeRegressor   84.365075      6.082314e+01
# 5                      Lasso   99.999933      1.257592e-01
# 6  GradientBoostingRegressor   94.534937      3.595991e+01
#
#    Mean_absolute_error  Mean_square_error  Cross_val_score_mean  \
# 0         3.681351e-28       3.681351e-28            100.000000
# 1         5.689247e-01       5.689247e-01             98.547887
# 2         5.112052e+01       5.112052e+01             32.686424
# 3         1.084647e+01       1.084647e+01             95.489375
# 4         3.699455e+01       3.699455e+01             90.966293
# 5         1.581538e-04       1.581538e-04             99.999913
# ...

# %%
# The above result shows that Linear Regressorr is giving the best result

# %%
from sklearn.externals import joblib
joblib.dump(lr,'Covid_19_Recovered.obj')
# Out:
# ['Covid_19_Recovered.obj']

# %%
model=joblib.load('Covid_19_Recovered.obj')

# %%
model.predict(x_test)
# Out:
# array([7.94697136, 8.60373779, 4.12713439, 4.83628191, 9.37449796,
#        8.15450018, 9.03157249, 6.85751406, 8.23589073, 7.54062153,
#        6.36130248, 6.96602419])
