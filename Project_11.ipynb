# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
ins_claims = pd.read_csv('Auto_Insurance_Claims_amount.csv')
ins_claims.head()
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus  ...  \
# 0  Bachelor           2/24/11         Employed  ...
# 1  Bachelor           1/31/11       Unemployed  ...
# 2  Bachelor           2/19/11         Employed  ...
# 3  Bachelor           1/20/11       Unemployed  ...
# 4  Bachelor            2/3/11         Employed  ...
#
#   Months Since Policy Inception  Number of Open Complaints Number of Policies  \
# 0                             5                          0                  1
# ...

# %%
ins_claims.tail(3)
# Out:
#      Customer Country State Code     State  Claim Amount Response  Coverage  \
# 9131  TD14365      US         MO  Missouri    816.389043       No  Extended
# 9132  UP19263      US         MO  Missouri    752.444244       No  Extended
# 9133  Y167826      US         MO  Missouri    261.183687       No  Extended
#
#      Education Effective To Date EmploymentStatus  ...  \
# 9131  Bachelor            2/6/11       Unemployed  ...
# 9132   College            2/3/11         Employed  ...
# 9133   College           2/14/11       Unemployed  ...
#
#      Months Since Policy Inception  Number of Open Complaints  \
# 9131                            37                          3
# 9132                             3                          0
# 9133                            90                          0
#
#      Number of Policies     Policy Type        Policy  Claim Reason  \
# 9131                  2  Corporate Auto  Corporate L2     Collision
# ...

# %%
ins_claims.columns
# Out:
# Index(['Customer', 'Country', 'State Code', 'State', 'Claim Amount',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Claim Reason',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
ins_claims.shape
# Out:
# (9134, 26)

# %%
ins_claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   Country                        9134 non-null   object
#  2   State Code                     9134 non-null   object
#  3   State                          9134 non-null   object
#  4   Claim Amount                   9134 non-null   float64
#  5   Response                       9134 non-null   object
#  6   Coverage                       9134 non-null   object
#  7   Education                      9134 non-null   object
#  8   Effective To Date              9134 non-null   object
#  9   EmploymentStatus               9134 non-null   object
#  10  Gender                         9134 non-null   object
#  11  Income                         9134 non-null   int64
# ...

# %% [markdown]
# # Cleansing of Data

# %%
# finding idea about the object data type
print("Customer_Uniqueness: ", ins_claims['Customer'].unique(), sep = '\n')
print("-"*60)
print("Country_Uniqueness: ", ins_claims['Country'].unique(), sep = '\n')
print("-"*60)
print("State Code_Uniqueness: ", ins_claims['State Code'].unique(), sep = '\n')
print("-"*60)
print("State_Uniqueness: ", ins_claims['State'].unique(), sep = '\n')
print("-"*60)
print("Response_Uniqueness: ", ins_claims['Response'].unique(), sep = '\n')
print("-"*60)
print("Coverage_Uniqueness: ", ins_claims['Coverage'].unique(), sep = '\n')
print("-"*60)
print("Education_Uniqueness: ", ins_claims['Education'].unique(), sep = '\n')
print("-"*60)
print("Effective To Date_Uniqueness: ", ins_claims['Effective To Date'].unique(), sep = '\n')
print("-"*60)
print("EmploymentStatus_Uniqueness: ", ins_claims['EmploymentStatus'].unique(), sep = '\n')
print("-"*60)
print("Gender_Uniqueness: ", ins_claims['Gender'].unique(), sep = '\n')
print("-"*60)
print("Location Code_Uniqueness: ", ins_claims['Location Code'].unique(), sep = '\n')
print("-"*60)
print("Marital Status_Uniqueness: ", ins_claims['Marital Status'].unique(), sep = '\n')
print("-"*60)
print("Policy Type_Uniqueness: ", ins_claims['Policy Type'].unique(), sep = '\n')
print("-"*60)
print("Policy_Uniqueness: ", ins_claims['Policy'].unique(), sep = '\n')
print("-"*60)
print("Claim Reason_Uniqueness: ", ins_claims['Claim Reason'].unique(), sep = '\n')
print("-"*60)
print("Sales Channel_Uniqueness: ", ins_claims['Sales Channel'].unique(), sep = '\n')
print("-"*60)
print("Vehicle Class_Uniqueness: ", ins_claims['Vehicle Class'].unique(), sep = '\n')
print("-"*60)
print("Vehicle Size_Uniqueness: ", ins_claims['Vehicle Size'].unique(), sep = '\n')
print("-"*60)
# Out:
# Customer_Uniqueness:
# ['BU79786' 'QZ44356' 'AI49188' ... 'TD14365' 'UP19263' 'Y167826']
# ------------------------------------------------------------
# Country_Uniqueness:
# ['US']
# ------------------------------------------------------------
# State Code_Uniqueness:
# ['KS' 'NE' 'OK' 'MO' 'IA']
# ------------------------------------------------------------
# State_Uniqueness:
# ['Kansas' 'Nebraska' 'Oklahoma' 'Missouri' 'Iowa']
# ------------------------------------------------------------
# Response_Uniqueness:
# ['No' 'Yes']
# ------------------------------------------------------------
# Coverage_Uniqueness:
# ['Basic' 'Extended' 'Premium']
# ------------------------------------------------------------
# Education_Uniqueness:
# ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
# ------------------------------------------------------------
# Effective To Date_Uniqueness:
# ['2/24/11' '1/31/11' '2/19/11' '1/20/11' '2/3/11' '1/25/11' '1/18/11'
# ...

# %%
# checking if there are any null value present in the dataset using heatmap
plt.figure(figsize=(12,8))
sns.heatmap(ins_claims.isnull(),cmap="Blues",annot=True)
plt.show()
# no null value present

# %%
# checking the null value without using visualization
ins_claims.isnull().sum()
# Out:
# Customer                         0
# Country                          0
# State Code                       0
# State                            0
# Claim Amount                     0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
# importing label encoder to convert dtype from object to int
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

# making a copy of dataset 
insurance_claims = ins_claims.copy()

# %%
# using label encoder to convert the dtype
list =['State','Response', 'Coverage', 'Education', 'Effective To Date',
       'EmploymentStatus', 'Gender','Location Code','Marital Status', 
       'Monthly Premium Auto', 'Policy Type', 'Policy', 'Claim Reason',
       'Sales Channel','Vehicle Class', 'Vehicle Size']
for i in list:
    insurance_claims[i] = label_encoder.fit_transform(insurance_claims[i])

# %%
# Customer, Country and Stae Code, dropping them as we do not require them at this point
insurance_claims.drop(['Customer', 'Country', 'State Code'],inplace=True,axis=1)

# %%
insurance_claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          9134 non-null   int32
#  1   Claim Amount                   9134 non-null   float64
#  2   Response                       9134 non-null   int32
#  3   Coverage                       9134 non-null   int32
#  4   Education                      9134 non-null   int32
#  5   Effective To Date              9134 non-null   int32
#  6   EmploymentStatus               9134 non-null   int32
#  7   Gender                         9134 non-null   int32
#  8   Income                         9134 non-null   int64
#  9   Location Code                  9134 non-null   int32
#  10  Marital Status                 9134 non-null   int32
#  11  Monthly Premium Auto           9134 non-null   int64
# ...

# %%
insurance_claims.shape
# Out:
# (9134, 23)

# %% [markdown]
# # Summary Statistics

# %%
insurance_claims.describe()
# Out:
#              State  Claim Amount     Response     Coverage    Education  \
# count  9134.000000   9134.000000  9134.000000  9134.000000  9134.000000
# mean      1.722684    800.494047     0.143201     0.480622     1.554084
# std       1.312397    687.096761     0.350297     0.655817     1.381978
# min       0.000000    189.800768     0.000000     0.000000     0.000000
# 25%       0.000000    399.425179     0.000000     0.000000     0.000000
# 50%       2.000000    578.018220     0.000000     0.000000     1.000000
# 75%       3.000000    896.216704     0.000000     1.000000     3.000000
# max       4.000000   8332.538119     1.000000     2.000000     4.000000
#
#        Effective To Date  EmploymentStatus       Gender        Income  \
# count        9134.000000       9134.000000  9134.000000   9134.000000
# mean           28.625575          1.825706     0.490037  37657.380009
# std            17.017215          1.347793     0.499928  30379.904734
# ...

# %% [raw]
# """
# Findings
# 1. Mean and 50% percentile there are variations in data
# 2. in 75% and max there are huge difference in claim amout,income, total claim amount columns
# 3. Looking at the findings it seems there are outliers present
#
# """

# %% [markdown]
# # Data Visualization

# %%
insurance_claims.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C8A9DE108>,
# ...
#       dtype=object)

# %%
# Finding what is the Claim amount across Satate
sns.factorplot('Claim Amount','State',data=ins_claims,size=8,aspect=0.8,palette='winter',join=False)

# %%
# # Finding what is the Total Claim Amount across Satate
plt.figure(figsize=(18,5))
sns.lineplot(x=ins_claims['State'],y=ins_claims["Total Claim Amount"],data=ins_claims)
plt.title("Total Claim Amount across Satate")
plt.ylabel("Total Claim Amount")
plt.xlabel("Satate")
plt.show()

# %%
# Trying to dipict the rerlationship between Claim Amount and Education

chart = sns.countplot(ins_claims['Claim Amount'], hue=ins_claims['Education'])

# %%
# Finding what is the Coverage across Satate
sns.factorplot('Coverage','State',data=insurance_claims,size=8,aspect=0.8,palette='winter',join=False)

# %%
# Finding what is the Claim Amount across Vehicle Class
sns.factorplot('Claim Amount','Vehicle Class',data=ins_claims,size=8,aspect=0.8,palette='winter',join=False)

# %%
# Finding what is the Number of Open Complaints across Satate
sns.factorplot('Number of Open Complaints','State',data=ins_claims,size=8,aspect=0.8,palette='winter',join=False)

# %%
# Finding what is the Income across Satate
sns.factorplot('Income','State',data=ins_claims,size=8,aspect=0.8,palette='winter',join=False)

# %%
# Finding what is the Number of Policies across Satate
sns.factorplot('Number of Policies','State',data=ins_claims,size=8,aspect=0.8,palette='winter',join=False)

# %%
# Finding what is the Number of Claim Amount across Policy Type
sns.factorplot('Claim Amount','Policy Type',data=ins_claims,size=8,aspect=0.8,palette='winter',join=False)

# %%
# Finding what is the Number of Income across Vehicle Class
sns.factorplot('Income','Vehicle Class',data=ins_claims,size=8,aspect=0.8,palette='winter',join=False)

# %%
plt.figure(figsize=(12,8))
plt.title("Distribution of Total Claim Amount")
price = insurance_claims['Total Claim Amount'].values
sns.distplot(price, color = 'red')

# %%
plt.figure(figsize=(12,8))
plt.title("Distribution of Claim Amount")
price = insurance_claims['Claim Amount'].values
sns.distplot(price, color = 'blue')

# %%
# Bivirate Analysis
sns.pairplot(insurance_claims)

# %% [markdown]
# # Checking Correlation

# %%
dfcor=insurance_claims.corr()
dfcor
# Out:
#                                   State  Claim Amount  Response  Coverage  \
# State                          1.000000     -0.006629 -0.001732  0.007558
# Claim Amount                  -0.006629      1.000000 -0.008930  0.168040
# Response                      -0.001732     -0.008930  1.000000  0.000642
# Coverage                       0.007558      0.168040  0.000642  1.000000
# Education                      0.004256      0.026038  0.000285  0.021573
# Effective To Date             -0.000448     -0.012978 -0.043133  0.005482
# EmploymentStatus              -0.004054     -0.034846 -0.016703  0.003239
# Gender                         0.000545     -0.013610  0.004396 -0.014448
# Income                         0.002682      0.024366  0.011932 -0.010646
# Location Code                  0.001382      0.004854  0.001729 -0.020176
# Marital Status                -0.008975     -0.026003 -0.094843  0.002956
# Monthly Premium Auto          -0.004377      0.398061  0.008616  0.455451
# ...

# %%
# generating heatmap to check the correlation amount features
plt.figure(figsize=(18,8))
sns.heatmap(dfcor,cmap='ocean_r',linewidths=2,fmt=".2f",annot=True)

# dark colour represent positive correlation whereas lighter colour represent negative correlation

# %% [markdown]
# # Plotting Outliers

# %%
insurance_claims.shape
# Out:
# (9134, 23)

# %%
collist = insurance_claims.columns.values
ncol=23
nrows=10

# %%
plt.figure(figsize=(2*ncol,10*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(insurance_claims[collist[i]],color='blue',orient='v')
    plt.tight_layout()

# %%
# finding outliers if there are any in the dataset

from scipy.stats import zscore
z_score=abs(zscore(insurance_claims))
print(insurance_claims.shape)
df_claim_amount = insurance_claims.loc[(z_score<3).all(axis=1)]
print(df_claim_amount.shape)
# outliners have been removed and the new shape of the dataset is reflection below
# Out:
# (9134, 23)
# (8446, 23)

# %% [markdown]
# # Checking Skewness

# %%
df_claim_amount.skew()
# data reflects mostly positive skewness
# Out:
# State                            0.019344
# Claim Amount                     1.858133
# Response                         2.025904
# Coverage                         1.079865
# Education                        0.337276
# Effective To Date                0.031570
# EmploymentStatus                 0.843636
# Gender                           0.043589
# Income                           0.283764
# Location Code                    0.012237
# Marital Status                  -0.099959
# Monthly Premium Auto             1.282570
# Months Since Last Claim          0.283319
# Months Since Policy Inception    0.049932
# Number of Open Complaints        2.573713
# Number of Policies               1.226468
# Policy Type                     -0.461960
# Policy                          -0.416009
# Claim Reason                     0.724396
# Sales Channel                    0.502705
# Total Claim Amount               0.708809
# Vehicle Class                    0.404900
# ...

# %%
plt.figure(figsize=(23,36))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df_claim_amount[collist[i]],kde_kws={'bw':0.1})

# %%
# treating skewness with log
import numpy as np
for col in df_claim_amount.columns:
    if df_claim_amount.skew().loc[col]>0.55:
        df_claim_amount[col] = np.log1p(df_claim_amount[col])

df_claim_amount.skew()
# skewness still presense
# Out:
# State                            0.019344
# Claim Amount                     0.362915
# Response                         2.025904
# Coverage                         0.749078
# Education                        0.337276
# Effective To Date                0.031570
# EmploymentStatus                 0.406276
# Gender                           0.043589
# Income                           0.283764
# Location Code                    0.012237
# Marital Status                  -0.099959
# Monthly Premium Auto            -0.545176
# Months Since Last Claim          0.283319
# Months Since Policy Inception    0.049932
# Number of Open Complaints        2.028493
# Number of Policies               0.638413
# Policy Type                     -0.461960
# Policy                          -0.416009
# Claim Reason                     0.211740
# Sales Channel                    0.502705
# Total Claim Amount              -1.932325
# Vehicle Class                    0.404900
# ...

# %%
# treating with square root
list = ['Coverage','Response','Number of Open Complaints','Number of Policies']
for i in list:
    df_claim_amount[i]=np.sqrt(df_claim_amount[i])

df_claim_amount.skew()
# skewness still reflecting
# Out:
# State                            0.019344
# Claim Amount                     0.362915
# Response                         2.025904
# Coverage                         0.558981
# Education                        0.337276
# Effective To Date                0.031570
# EmploymentStatus                 0.406276
# Gender                           0.043589
# Income                           0.283764
# Location Code                    0.012237
# Marital Status                  -0.099959
# Monthly Premium Auto            -0.545176
# Months Since Last Claim          0.283319
# Months Since Policy Inception    0.049932
# Number of Open Complaints        1.710303
# Number of Policies               0.417309
# Policy Type                     -0.461960
# Policy                          -0.416009
# Claim Reason                     0.211740
# Sales Channel                    0.502705
# Total Claim Amount              -1.932325
# Vehicle Class                    0.404900
# ...

# %%
# treating with cube root
list = ['Response','Number of Open Complaints']
for i in list:
    df_claim_amount[i]=np.sqrt(df_claim_amount[i])

df_claim_amount.skew()
# skewness still reflecting
# Out:
# State                            0.019344
# Claim Amount                     0.362915
# Response                         2.025904
# Coverage                         0.558981
# Education                        0.337276
# Effective To Date                0.031570
# EmploymentStatus                 0.406276
# Gender                           0.043589
# Income                           0.283764
# Location Code                    0.012237
# Marital Status                  -0.099959
# Monthly Premium Auto            -0.545176
# Months Since Last Claim          0.283319
# Months Since Policy Inception    0.049932
# Number of Open Complaints        1.629726
# Number of Policies               0.417309
# Policy Type                     -0.461960
# Policy                          -0.416009
# Claim Reason                     0.211740
# Sales Channel                    0.502705
# Total Claim Amount              -1.932325
# Vehicle Class                    0.404900
# ...

# %% [markdown]
# # Seperating input and output for Regression

# %%
df_claim_amount.shape
# Out:
# (8446, 23)

# %%
# defining x and y
x = df_claim_amount.drop("Claim Amount",axis=1)
y = df_claim_amount["Claim Amount"].copy()

# %%
x.head(3)
# Out:
#    State  Response  Coverage  Education  Effective To Date  EmploymentStatus  \
# 0      1       0.0  0.000000          0                 47          0.693147
# 1      3       0.0  0.832555          0                 24          1.609438
# 2      4       0.0  1.048147          0                 41          0.693147
#
#    Gender  Income  Location Code  Marital Status  ...  \
# 0       0   56274              1               1  ...
# 1       0       0              1               2  ...
# 2       0   48767              1               1  ...
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                        0.0
# 1                             42                        0.0
# 2                             38                        0.0
#
#    Number of Policies  Policy Type  Policy  Claim Reason  Sales Channel  \
# 0            0.832555            0       2      0.000000              0
# ...

# %%
y.head(3)
# Out:
# 0    5.625287
# 1    6.549584
# 2    7.162198
# Name: Claim Amount, dtype: float64

# %%
x.shape
# Out:
# (8446, 22)

# %%
y.shape
# Out:
# (8446,)

# %%
# Scaling down using standard scaler

from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
x = ss.fit_transform(x)
x
# Out:
# array([[-0.55121503, -0.41050133, -0.77270683, ...,  0.23827589,
#          1.47704086, -0.16174647],
#        [ 0.97344918, -0.41050133,  1.16344492, ...,  1.46661471,
#         -0.89059761, -0.16174647],
#        [ 1.73578128, -0.41050133,  1.66481711, ...,  0.67841822,
#          1.47704086, -0.16174647],
#        ...,
#        [ 0.21111707, -0.41050133,  1.16344492, ...,  1.05839199,
#         -0.89059761, -0.16174647],
#        [ 0.21111707, -0.41050133,  1.16344492, ...,  0.9050613 ,
#         -0.89059761, -2.02293271],
#        [ 0.21111707, -0.41050133,  1.16344492, ...,  0.19239053,
#          1.47704086, -0.16174647]])

# %%
# importing important libraries

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso
from sklearn.ensemble import GradientBoostingRegressor

# %%
# finding best random state between 42 to 100 with test_size=0.22
max_r_score = 0
for r_state in range(42,101):
    x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = r_state, test_size=0.22)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    y_predict = lr.predict(x_test)
    r2_scr = r2_score(y_test, y_predict)
    print("r2_score corresponding to random state: ",r_state," is: ", r2_scr)
    if r2_scr > max_r_score:
        max_r_score = r2_scr
        final_r_state = r_state
    print()
    print()
    print("Maximum r2 score corresponding to",final_r_state, "is ",max_r_score)
# Out:
# r2_score corresponding to random state:  42  is:  0.30399604529232094
#
#
# Maximum r2 score corresponding to 42 is  0.30399604529232094
# r2_score corresponding to random state:  43  is:  0.29844576775914
#
#
# Maximum r2 score corresponding to 42 is  0.30399604529232094
# r2_score corresponding to random state:  44  is:  0.33606090574302805
#
#
# Maximum r2 score corresponding to 44 is  0.33606090574302805
# r2_score corresponding to random state:  45  is:  0.31040340773823816
#
#
# Maximum r2 score corresponding to 44 is  0.33606090574302805
# r2_score corresponding to random state:  46  is:  0.27662812281627913
#
#
# Maximum r2 score corresponding to 44 is  0.33606090574302805
# r2_score corresponding to random state:  47  is:  0.3186579331045617
#
#
# Maximum r2 score corresponding to 44 is  0.33606090574302805
# r2_score corresponding to random state:  48  is:  0.2886354878452887
#
#
# Maximum r2 score corresponding to 44 is  0.33606090574302805
# ...

# %%
# since the maximun r2 score is comming around 0.34 with random state 61. As the score is very low 
# hence checking with other models
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 61, test_size = 0.22)

# %%
x_train.shape
# Out:
# (6587, 22)

# %%
y_train.shape
# Out:
# (6587,)

# %%
x_test.shape
# Out:
# (1859, 22)

# %%
y_test.shape
# Out:
# (1859,)

# %%
# finding the best parameters for each model using gridsearchCV

# %%
svr=SVR()
parameters = {'kernel':('linear','poly','rbf'), 'C':[1,10]}
svgs = GridSearchCV(svr, parameters, cv = 5)
svgs.fit(x_train,y_train)
svgs.best_params_
# Out:
# {'C': 1, 'kernel': 'rbf'}

# %%
knn = KNeighborsRegressor()
parameters = {'n_neighbors':range(1,30)}
knngs = GridSearchCV(knn, parameters, cv = 5)
knngs.fit(x_train, y_train)
knngs.best_params_
# Out:
# {'n_neighbors': 11}

# %%
rfr = RandomForestRegressor()
parameters = {'n_estimators':[50,100,150,200,250,300]}
rfgs = GridSearchCV(rfr, parameters, cv = 5)
rfgs.fit(x_train, y_train)
rfgs.best_params_
# Out:
# {'n_estimators': 300}

# %%
dtr = DecisionTreeRegressor()
parameters = {'criterion':('mse','friendman_mse', 'mse')}
dtgs = GridSearchCV(dtr, parameters, cv = 5)
dtgs.fit(x_train, y_train)
dtgs.best_params_
# Out:
# {'criterion': 'mse'}

# %%
lso = Lasso()
parameters = {'alpha':[0.001,0.01,0.1,1]}
lsgs = GridSearchCV(lso, parameters, cv = 5)
lsgs.fit(x_train, y_train)
lsgs.best_params_
# Out:
# {'alpha': 0.01}

# %%
gbr = GradientBoostingRegressor()
parameters = {'learning_rate':[0.001,0.01,0.1,1], 'n_estimators':[10,100,500,1000]}
gbgs = GridSearchCV(gbr, parameters, cv = 5)
gbgs.fit(x_train, y_train)
gbgs.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 500}

# %%
lr = LinearRegression()
svr = SVR(C=1, kernel = 'rbf')
knn = KNeighborsRegressor(n_neighbors = 11)
rfr = RandomForestRegressor(n_estimators = 300)
dtr = DecisionTreeRegressor(criterion ='mse')
lso = Lasso(alpha =0.01 )
gbr = GradientBoostingRegressor(learning_rate = 0.1, n_estimators = 500)

# %%
models = []
models.append(('LineatRegression', lr))
models.append(('SVR', svr))
models.append(('KNeighborsRegressor', knn))
models.append(('RandomForestRegressor', rfr))
models.append(('DecisionTreeRegressor', dtr))
models.append(('Lasso', lso))
models.append(('GradientBoostingRegressor', gbr))

# %%
# Testing all required models with best parameters calculated

Model = []
score = []
rmse = []
mae = []
mse = []
cvs = []
std = []

for name,model in models:
    print ('******************', name ,'********************')
    print("\n")
    Model.append(name)
    model.fit(x_train, y_train)
    print(model)
    pred = model.predict(x_test)
    print("\n")
    rscore = r2_score(y_test, pred)
    print("r2 Score =", rscore)
    score.append(rscore*100)
    print("\n")
    RMS = np.sqrt(mean_squared_error(y_test, pred))
    print("RMSE =", RMS)
    rmse.append(RMS*100)
    print("\n")
    MA = mean_absolute_error(y_test, pred)
    print("MAE =", MA)
    mae.append(MA*100)
    print("\n")
    MS = mean_squared_error(y_test, pred)
    print("MSE =", MS)
    mse.append(MS*100)
    print("\n")
    cvscore = cross_val_score(model, x, y, cv = 10).mean()
    print("Cross_Val_Score =", cvscore)
    cvs.append(cvscore*100)
    print("\n")
    stdscore = cross_val_score(model, x, y, cv = 10).std()
    print("Standard Deviation =", stdscore)
    std.append(stdscore*100)
    print("\n\n")
# Out:
# ****************** LineatRegression ********************
#
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
#
# r2 Score = 0.34321404829562874
#
#
# RMSE = 0.48205746811665867
#
#
# MAE = 0.37527431839248504
#
#
# MSE = 0.2323794025670434
#
#
# Cross_Val_Score = 0.306627704185665
#
#
# Standard Deviation = 0.027744785748640383
#
#
#
# ****************** SVR ********************
#
#
# SVR(C=1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
#
#
# r2 Score = 0.6815041738273746
#
#
# RMSE = 0.3356902756184157
#
#
# MAE = 0.22419199640167659
#
#
# MSE = 0.1126879611447679
#
#
# Cross_Val_Score = 0.67119190844276
#
#
# Standard Deviation = 0.021573288053589622
#
#
#
# ****************** KNeighborsRegressor ********************
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
# ...

# %%
import pandas as pd
result = pd.DataFrame({'Model': Model, 'r2_score': score, 'Root_mean_square': rmse, 'Mean_absolute_error': mse, 'Mean_square_error': mse, 'Cross_val_score_mean': cvs, 'Cross_val_score_Std': std})
result
# Out:
#                        Model   r2_score  Root_mean_square  \
# 0           LineatRegression  34.321405         48.205747
# 1                        SVR  68.150417         33.569028
# 2        KNeighborsRegressor  33.184087         48.621331
# 3      RandomForestRegressor  92.748269         16.017980
# 4      DecisionTreeRegressor  86.732437         21.666186
# 5                      Lasso  33.801820         48.396050
# 6  GradientBoostingRegressor  92.491667         16.298913
#
#    Mean_absolute_error  Mean_square_error  Cross_val_score_mean  \
# 0            23.237940          23.237940             30.662770
# 1            11.268796          11.268796             67.119191
# 2            23.640338          23.640338             33.247053
# 3             2.565757           2.565757             92.106981
# 4             4.694236           4.694236             84.602594
# 5            23.421776          23.421776             30.547157
# ...

# %%
# above result shows that RandomForestRegressor is giving the best result

# %%
from sklearn.externals import joblib
joblib.dump(rfr,'Auto_Insurance_Claims_amount.obj')
# Out:
# ['Auto_Insurance_Claims_amount.obj']

# %%
model=joblib.load('Auto_Insurance_Claims_amount.obj')

# %%
model.predict(x_test)
# Out:
# array([6.43055141, 7.33998398, 6.70048669, ..., 6.28547378, 7.26510079,
#        5.94866424])
